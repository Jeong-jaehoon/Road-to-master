# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('분석에사용할데이터.xlsx')

# %%
pd.set_option('display.max_columns', None)

# %%
raw_data = data.copy()

# %%
data.head()
# Out:
#    report_time_simple         report_time  지점           주소        사고원인  구조상태  \
# 0 2010-01-01 07:00:00 2010-01-01 07:49:00  태백   강원도 태백시 혈동        산악기타    경상
# 1 2010-01-01 11:00:00 2010-01-01 11:16:00  태백   강원도 태백시 혈동  개인(급.만성)질환    기타
# 2 2010-01-01 11:00:00 2010-01-01 11:31:00  태백  강원도 태백시 소도동        일반조난    미상
# 3 2010-01-02 07:00:00 2010-01-02 07:44:00  태백  강원도 태백시 황지동        산악기타    경상
# 4 2010-01-02 11:00:00 2010-01-02 11:34:00  태백  강원도 태백시 소도동        산악기타  안전구조
#
#    처리결과       mountain  인접산                  산주소       산id         lon  \
# 0  인명구조   강원도 태백시 혈동 산  태백산           강원 태백시 소도동  15168010  128.916106
# 1  인명구조   강원도 태백시 혈동 산  태백산           강원 태백시 소도동  15168010  128.916106
# 2  인명검색  강원도 태백시 소도동 산  태백산           강원 태백시 소도동  15168010  128.916106
# 3  인명구조  강원도 태백시 황지동 산  함백산  강원 태백시 황지동 산 176-12  27446004  128.918047
# 4  인명구조  강원도 태백시 소도동 산  태백산           강원 태백시 소도동  15168010  128.916106
#
#          lat  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  풍속 QC플래그  \
# ...

# %%
set(data['기온 QC플래그'])
# Out:
# {0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  9.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
data.shape
# Out:
# (84247, 47)

# %%
data[data['기온 QC플래그'] == 0.0]
# Out:
#        report_time_simple         report_time  지점                주소  \
# 0     2010-01-01 07:00:00 2010-01-01 07:49:00  태백        강원도 태백시 혈동
# 1     2010-01-01 11:00:00 2010-01-01 11:16:00  태백        강원도 태백시 혈동
# 2     2010-01-01 11:00:00 2010-01-01 11:31:00  태백       강원도 태백시 소도동
# 3     2010-01-02 07:00:00 2010-01-02 07:44:00  태백       강원도 태백시 황지동
# 4     2010-01-02 11:00:00 2010-01-02 11:34:00  태백       강원도 태백시 소도동
# 5     2010-01-02 16:00:00 2010-01-02 16:37:00  태백       강원도 태백시 소도동
# 6     2010-01-01 00:00:00 2010-01-01 00:12:00  남원  전라북도 남원시 운봉읍 공안리
# 7     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 8     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 9     2010-01-01 06:00:00 2010-01-01 06:25:00  서울     서울특별시 관악구 봉천동
# 10    2010-01-01 06:00:00 2010-01-01 06:31:00  안동       경기도 광명시 하안동
# 11    2010-01-01 07:00:00 2010-01-01 07:17:00  문경  경상북도 문경시 문경읍 상초리
# 12    2010-01-01 07:00:00 2010-01-01 07:30:00  창원      경상남도 마산시 교방동
# ...

# %%
data = data[data['기온 QC플래그'] == 0.0]

# %%
data['강수량(mm)'] = data['강수량(mm)'].fillna(0)

# %%
data =  data[data['풍속 QC플래그'] == 0.0]

# %%
data = data[data['습도 QC플래그'] == 0.0]

# %%
data.shape
# Out:
# (83591, 47)

# %%
data.info
# Out:
# <bound method DataFrame.info of        report_time_simple         report_time  지점                주소  \
# 0     2010-01-01 07:00:00 2010-01-01 07:49:00  태백        강원도 태백시 혈동
# 1     2010-01-01 11:00:00 2010-01-01 11:16:00  태백        강원도 태백시 혈동
# 2     2010-01-01 11:00:00 2010-01-01 11:31:00  태백       강원도 태백시 소도동
# 3     2010-01-02 07:00:00 2010-01-02 07:44:00  태백       강원도 태백시 황지동
# 4     2010-01-02 11:00:00 2010-01-02 11:34:00  태백       강원도 태백시 소도동
# 5     2010-01-02 16:00:00 2010-01-02 16:37:00  태백       강원도 태백시 소도동
# 6     2010-01-01 00:00:00 2010-01-01 00:12:00  남원  전라북도 남원시 운봉읍 공안리
# 7     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 8     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 9     2010-01-01 06:00:00 2010-01-01 06:25:00  서울     서울특별시 관악구 봉천동
# 10    2010-01-01 06:00:00 2010-01-01 06:31:00  안동       경기도 광명시 하안동
# 11    2010-01-01 07:00:00 2010-01-01 07:17:00  문경  경상북도 문경시 문경읍 상초리
# ...

# %%
data.drop(['풍향 QC플래그', '풍향(16방위)'], axis =1, inplace=True)

# %%
data.drop(['증기압(hPa)'], axis = 1, inplace=True)

# %%
data.shape
# Out:
# (83591, 44)

# %%
data
# Out:
# (83572, 47)

# %%
data = data[data['현지기압 QC플래그'] == 0.0]

# %%
data.drop(['해면기압(hPa)', '해면기압 QC플래그'], axis =1, inplace=True)
# Out:
# C:\anaconda\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data.shape
# Out:
# (83559, 42)

# %%
data.drop(['일사(MJ/m2)'], axis = 1, inplace =True)

# %%
data.drop(['일조(hr)', '일조 QC플래그'], axis = 1, inplace=True)
# Out:
# C:\anaconda\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data.shape
# Out:
# (83559, 39)

# %%
data['적설(cm)'] = data['적설(cm)'].fillna(0)

# %%
data.drop(['3시간신적설(cm)', '전운량(10분위)', '중하층운량(10분위)', '운형(운형약어)','최저운고(100m )','시정(10m)', '지면상태(지면상태코드)','현상번호(국내식)'], axis = 1, inplace=True)

# %%
data.drop(['5cm 지중온도(°C)', '10cm 지중온도(°C)', '20cm 지중온도(°C)', '30cm 지중온도(°C)'], axis =1, inplace = True)

# %%
data.drop(['강수량 QC플래그', '풍속 QC플래그'], axis =1, inplace=True)

# %%
data.shape
# Out:
# (83559, 25)

# %%
data = data[data['지면온도 QC플래그'] ==0]

# %%
data.drop(['기온 QC플래그', '지면온도 QC플래그', '습도 QC플래그', '현지기압 QC플래그'], axis = 1, inplace=True)
# Out:
# C:\anaconda\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data.to_excel('data.xlsx')
