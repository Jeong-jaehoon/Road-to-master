# %%
import numpy as np
import pandas as pd

# %%
# !pip install keras
# Out:
# Collecting keras
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
# Requirement already satisfied: numpy>=1.9.1 in c:\anaconda\lib\site-packages (from keras) (1.16.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\anaconda\lib\site-packages (from keras) (1.1.0)
# Requirement already satisfied: pyyaml in c:\anaconda\lib\site-packages (from keras) (5.1.2)
# Requirement already satisfied: h5py in c:\anaconda\lib\site-packages (from keras) (2.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\anaconda\lib\site-packages (from keras) (1.12.0)
# Requirement already satisfied: scipy>=0.14 in c:\anaconda\lib\site-packages (from keras) (1.2.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\anaconda\lib\site-packages (from keras) (1.0.8)
# Installing collected packages: keras
# Successfully installed keras-2.2.4

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from keras.layers import Dense, Input, concatenate, Dropout
from keras.models import Model
from keras.optimizers import rmsprop

# %%
data = pd.read_excel('data2.xlsx')

# %%
data
# Out:
#        report_time_simple         report_time  지점                주소  \
# 0     2010-01-01 07:00:00 2010-01-01 07:49:00  태백        강원도 태백시 혈동
# 1     2010-01-01 11:00:00 2010-01-01 11:16:00  태백        강원도 태백시 혈동
# 2     2010-01-01 11:00:00 2010-01-01 11:31:00  태백       강원도 태백시 소도동
# 3     2010-01-02 07:00:00 2010-01-02 07:44:00  태백       강원도 태백시 황지동
# 4     2010-01-02 11:00:00 2010-01-02 11:34:00  태백       강원도 태백시 소도동
# 5     2010-01-02 16:00:00 2010-01-02 16:37:00  태백       강원도 태백시 소도동
# 6     2010-01-01 00:00:00 2010-01-01 00:12:00  남원  전라북도 남원시 운봉읍 공안리
# 7     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 8     2010-01-01 05:00:00 2010-01-01 05:43:00  진도  전라남도 진도군 진도읍 남동리
# 9     2010-01-01 06:00:00 2010-01-01 06:25:00  서울     서울특별시 관악구 봉천동
# 10    2010-01-01 06:00:00 2010-01-01 06:31:00  안동       경기도 광명시 하안동
# 11    2010-01-01 07:00:00 2010-01-01 07:17:00  문경  경상북도 문경시 문경읍 상초리
# 12    2010-01-01 07:00:00 2010-01-01 07:30:00  창원      경상남도 마산시 교방동
# 13    2010-01-01 07:00:00 2010-01-01 07:33:00  청주  충청북도 청주시 흥덕구 산남동
# 14    2010-01-01 08:00:00 2010-01-01 08:01:00  부여  충청남도 부여군 석성면 증산리
# 15    2010-01-01 08:00:00 2010-01-01 08:04:00  부산      부산광역시 남구 용호동
# 16    2010-01-01 08:00:00 2010-01-01 08:18:00  밀양      경상남도 밀양시 가곡동
# 17    2010-01-01 08:00:00 2010-01-01 08:22:00  서울     서울특별시 도봉구 도봉동
# 18    2010-01-01 08:00:00 2010-01-01 08:32:00  수원       경기도 의왕시 내손동
# 19    2010-01-01 08:00:00 2010-01-01 08:40:00  서울     서울특별시 광진구 광장동
# 20    2010-01-01 08:00:00 2010-01-01 08:40:00  대전  충청남도 계룡시 엄사면 향한리
# 21    2010-01-01 08:00:00 2010-01-01 08:40:00  대전  충청남도 계룡시 엄사면 엄사리
# 22    2010-01-01 08:00:00 2010-01-01 08:41:00  부산     부산광역시 사하구 괴정동
# 23    2010-01-01 08:00:00 2010-01-01 08:48:00  서울  경기도 남양주시 별내면 화접리
# 83461 2018-12-30 14:00:00 2018-12-30 14:28:00  수원   경기도 안양시 만안구 석수동
# 83462 2018-12-30 15:00:00 2018-12-30 15:00:00  춘천       강원도 춘천시 석사동
# 83463 2018-12-30 16:00:00 2018-12-30 16:06:00  홍천   강원도 평창군 방림면 운교리
# 83464 2018-12-30 16:00:00 2018-12-30 16:37:00  서울     서울특별시 강북구 우이동
# 83465 2018-12-30 17:00:00 2018-12-30 17:03:00  대전  충청북도 옥천군 안남면 연주리
# 83466 2018-12-30 17:00:00 2018-12-30 17:06:00  울산  울산광역시 울주군 청량읍 율리
#
#              사고원인  구조상태  처리결과            mountain      인접산  \
# 0            산악기타    경상  인명구조        강원도 태백시 혈동 산      태백산
# 1      개인(급.만성)질환    기타  인명구조        강원도 태백시 혈동 산      태백산
# 2            일반조난    미상  인명검색       강원도 태백시 소도동 산      태백산
# 3            산악기타    경상  인명구조       강원도 태백시 황지동 산      함백산
# 4            산악기타  안전구조  인명구조       강원도 태백시 소도동 산      태백산
# 5            산악기타  안전구조  인명구조       강원도 태백시 소도동 산      태백산
# 6            일반조난    기타  인명구조  전라북도 남원시 운봉읍 공안리 산      세걸산
# 7            일반조난    기타  안전조치  전라남도 진도군 진도읍 남동리 산       남산
# 8            일반조난    미상  안전조치  전라남도 진도군 진도읍 남동리 산       남산
# 9            실족추락    미상  인명구조     서울특별시 관악구 봉천동 산      청룡산
# 10           실족추락    경상  인명구조       경기도 광명시 하안동 산      구름산
# 11           일반조난    미상    기타  경상북도 문경시 문경읍 상초리 산      주흘산
# 12           실족추락  안전구조  인명구조      경상남도 마산시 교방동 산      부엉산
# 13     개인(급.만성)질환    사망  인명구조  충청북도 청주시 흥덕구 산남동 산      구룡산
# 14           산악기타    경상  인명구조  충청남도 부여군 석성면 증산리 산      소반산
# 15           산악기타    경상  인명구조      부산광역시 남구 용호동 산     봉오리산
# 16           일반조난    경상  인명구조      경상남도 밀양시 가곡동 산      용두산
# 17           실족추락    미상  인명구조     서울특별시 도봉구 도봉동 산      도봉산
# 18           산악기타    경상  인명구조       경기도 의왕시 내손동 산      모락산
# 19           산악기타    미상  인명구조     서울특별시 광진구 광장동 산      아차산
# 20           실족추락    미상  인명구조  충청남도 계룡시 엄사면 향한리 산      향적산
# 21           산악기타    경상  인명구조  충청남도 계룡시 엄사면 엄사리 산      향적산
# 22           산악기타    미상  인명구조     부산광역시 사하구 괴정동 산      시약산
# 23           실족추락    경상  인명구조      경기도 남양주시 별내면 산      수락산
# 24           실족추락    경상  인명구조  충청남도 천안시 동남구 신부동 산      큰매산
# 25           실족추락    미상  인명구조     서울특별시 노원구 상계동 산      초안산
# 26           산악기타    미상  인명구조     서울특별시 도봉구 도봉동 산      도봉산
# 27           산악기타    미상    기타    강원도 양양군 서면 오색리 산      설악산
# 28           산악기타    경상  인명구조  경상북도 영주시 풍기읍 삼가리 산      소백산
# 29           실족추락    중상  인명구조      경상남도 통영시 사량면 산  사량도 지리산
# ...           ...   ...   ...                 ...      ...
# 83437        기타산악    경상  인명구조  경상남도 함양군 마천면 강청리 산     세석평전
# 83438        개인질환    미상  인명구조     부산광역시 해운대구 좌동 산      구곡산
# 83439        일반조난  안전구조  인명구조   강원도 정선군 정선읍 회동리 산     가리왕산
# 83440        기타산악    미상  인명구조    강원도 인제군 북면 용대리 산      오봉산
# 83441        개인질환    경상  인명구조    강원도 인제군 북면 용대리 산      오봉산
# 83442        기타산악    미상  안전조치  전라북도 고창군 고창읍 월곡리 산      방문산
# 83443        기타산악    미상    기타      울산광역시 북구 염포동 산      염포산
# 83444        기타산악  안전구조  인명구조      울산광역시 북구 염포동 산      염포산
# 83445        기타산악    경상  인명구조  전라북도 남원시 산내면 부운리 산      삼정산
# 83446        일반조난  안전구조  인명구조     서울특별시 은평구 진관동 산      이말산
# 83447        기타산악    미상  안전조치     서울특별시 도봉구 도봉동 산      도봉산
# 83448        기타산악    미상  인명구조    인천광역시 미추홀구 문학동 산      문학산
# 83449        실족추락  안전구조  인명구조     인천광역시 계양구 목상동 산      계양산
# 83450        기타산악    미상  안전조치      전라남도 여수시 적량동 산      배틀산
# 83451        기타산악    미상    기타   강원도 양구군 양구읍 웅진리 산      사명산
# 83452        기타산악    중상  인명구조  경상남도 함양군 함양읍 교산리 산      백암산
# 83453        실족추락    경상  인명구조   강원도 양구군 양구읍 웅진리 산      사명산
# 83454        기타산악    미상    기타       강원도 원주시 봉산동 산       봉산
# 83455        실족추락    미상  안전조치       강원도 원주시 봉산동 산       봉산
# 83456        개인질환    기타  인명구조     서울특별시 관악구 봉천동 산      청룡산
# 83457        기타산악    미상  인명구조     서울특별시 중랑구 상봉동 산      봉화산
# 83458        기타산악  안전구조  인명구조   강원도 인제군 인제읍 원대리 산      응봉산
# 83459        기타산악    미상  인명구조   강원도 인제군 인제읍 원대리 산      응봉산
# 83460        실족추락    경상  인명구조       강원도 원주시 봉산동 산       봉산
# 83461        기타산악    미상  안전조치   경기도 안양시 만안구 석수동 산      삼성산
# 83462        기타산악    경상  인명구조       강원도 춘천시 석사동 산      안마산
# 83463        실족추락    경상  인명구조   강원도 평창군 방림면 운교리 산      백덕산
# 83464        개인질환    미상  인명구조     서울특별시 강북구 우이동 산      삼각산
# 83465        기타산악  안전구조  인명구조  충청북도 옥천군 안남면 연주리 산      뒷동산
# 83466        기타산악    미상  인명구조  울산광역시 울주군 청량읍 율리 산      남암산
#
#                         산주소  ...         lon        lat  기온(°C)  강수량(mm)  \
# 0                강원 태백시 소도동  ...  128.916106  37.098986   -12.2      0.0
# 1                강원 태백시 소도동  ...  128.916106  37.098986    -8.0      0.0
# 2                강원 태백시 소도동  ...  128.916106  37.098986    -8.0      0.0
# 3       강원 태백시 황지동 산 176-12  ...  128.918047  37.161285    -6.0      0.0
# 4                강원 태백시 소도동  ...  128.916106  37.098986    -0.2      0.0
# 5                강원 태백시 소도동  ...  128.916106  37.098986     0.1      0.0
# 83463    -2.3      0.0      0.8   26.0      -19.2     0.0
# 83464    -1.0      0.0      1.7   24.0      -19.0     0.0
# 83465    -1.6      0.0      0.7   34.0      -15.4     0.0
# 83466     1.3      0.0      3.9   29.0      -14.8     0.0
#
# [83467 rows x 6 columns]

# %%
raw_data = data.copy()

# %%
data = raw_data.copy()

# %%
target = pd.DataFrame(data['사고원인'])

# %%
df = data[['기온(°C)', '강수량(mm)','풍속(m/s)','습도(%)', '이슬점온도(°C)', '적설(cm)','지면온도(°C)']]

# %%
df['강수여부'] = np.where(df['강수량(mm)']==0.0, 0, 1)

# %%
df['적설여부'] =np.where(df['적설(cm)']==0.0, 0, 1)

# %%
df
# Out:
#        기온(°C)  강수량(mm)  풍속(m/s)  습도(%)  이슬점온도(°C)  적설(cm)  지면온도(°C)
# 0       -12.2      0.0      2.2   29.0      -26.6     0.0     -12.6
# 1        -8.0      0.0      2.5   39.0      -19.5     0.0      -5.2
# 2        -8.0      0.0      2.5   39.0      -19.5     0.0      -5.2
# 3        -6.0      0.0      3.3   80.0       -8.8     0.0      -7.0
# 4        -0.2      0.0      3.4   80.0       -3.2     0.0      -1.6
# 5         0.1      0.0      1.0   82.0       -2.6     0.0      -0.5
# 6       -16.5      0.0      0.8   87.0      -18.1    13.8      -2.1
# 7        -5.6      0.0      5.9   92.0       -6.6     1.6       0.2
# 8        -5.6      0.0      5.9   92.0       -6.6     1.6       0.2
# 9       -12.4      0.0      1.6   57.0      -19.1     2.2      -7.1
# 10       -9.3      0.0      3.1   39.0      -20.7     0.0     -10.6
# 11       -9.9      0.0      4.3   30.0      -24.2     0.0     -10.3
# 12       -7.6      0.0      0.4   53.0      -15.5     0.0      -0.4
# 13      -11.4      0.0      0.6   69.0      -15.9     0.0      -8.7
# 14      -12.3      0.0      0.2   88.0      -13.8     0.0      -1.0
# 15       -5.4      0.0      0.9   44.0      -15.7     0.0      -6.4
# 16       -9.5      0.0      1.1   68.0      -14.3     0.0      -8.6
# 17      -12.6      0.0      1.5   54.0      -20.0     2.2      -7.2
# 18      -12.9      0.0      0.8   72.0      -16.8     0.5      -6.4
# 19      -12.6      0.0      1.5   54.0      -20.0     2.2      -7.2
# 20      -11.3      0.0      0.6   64.0      -16.7     0.0      -7.8
# 21      -11.3      0.0      0.6   64.0      -16.7     0.0      -7.8
# 22       -5.4      0.0      0.9   44.0      -15.7     0.0      -6.4
# 23      -12.6      0.0      1.5   54.0      -20.0     2.2      -7.2
# 24      -13.1      0.0      0.1   77.0      -16.2     0.3      -9.6
# 25      -11.7      0.0      1.6   43.0      -21.7     2.2      -7.0
# 26      -11.7      0.0      1.6   43.0      -21.7     2.2      -7.0
# 27       -4.8      0.0      5.4   24.0      -22.3     0.0      -6.0
# 28       -5.7      0.0      5.2   30.0      -20.5     0.0      -3.8
# 29       -1.1      0.0      1.2   46.0      -11.2     0.0      -1.8
# ...       ...      ...      ...    ...        ...     ...       ...
# 83437    -0.5      0.0      4.0   32.0      -15.2     0.0       1.4
# 83438     1.6      0.0      3.7   20.0      -19.0     0.0      13.8
# 83439    -4.0      0.0      2.8   17.0      -25.5     0.0       1.1
# 83440    -5.2      0.0      4.4   23.0      -23.1     0.0       0.8
# 83441    -4.7      0.0      4.1   22.0      -23.2     0.0       0.5
# 83442    -2.6      0.0      5.2   64.0       -8.4    18.0       0.1
# 83443    -1.5      0.0      3.0   17.0      -23.4     0.0      -1.0
# 83444    -1.5      0.0      3.0   17.0      -23.4     0.0      -1.0
# 83445   -10.3      0.0      1.2   78.0      -13.4     0.0      -7.7
# 83446    -9.8      0.0      2.4   34.0      -22.7     0.0      -8.5
# 83447    -8.4      0.0      1.2   32.0      -22.1     0.0      -3.7
# 83448    -6.9      0.0      2.3   35.0      -19.8     0.0      -0.6
# 83449    -6.9      0.0      2.3   35.0      -19.8     0.0      -0.6
# 83450     1.0      0.0      4.6   31.0      -14.2     0.0      11.2
# 83451    -6.0      0.0      1.0   42.0      -16.8     0.0      -2.7
# 83452     2.0      0.0      2.4   23.0      -17.0     0.0       3.3
# 83453    -4.5      0.0      0.8   31.0      -19.1     0.0      -0.5
# 83454    -4.4      0.0      1.1   24.0      -21.9     0.0       2.9
# 83455    -4.4      0.0      1.1   24.0      -21.9     0.0       2.9
# 83456    -3.2      0.0      1.4   26.0      -20.0     0.0       6.5
# 83457    -3.2      0.0      1.4   26.0      -20.0     0.0       6.5
# 83458    -2.9      0.0      2.3   27.0      -19.3     0.0       2.0
# 83459    -2.9      0.0      2.3   27.0      -19.3     0.0       2.0
# 83460    -3.1      0.0      0.9   23.0      -21.3     0.0       0.2
# 83461    -2.6      0.0      1.2   27.0      -19.0     0.0      -2.4
# 83462    -2.2      0.0      0.7   29.0      -17.8     0.0       1.6
# 83463    -2.3      0.0      0.8   26.0      -19.2     0.0      -1.8
# 83464    -1.0      0.0      1.7   24.0      -19.0     0.0       2.1
# 83465    -1.6      0.0      0.7   34.0      -15.4     0.0      -1.3
# 83466     1.3      0.0      3.9   29.0      -14.8     0.0      -0.3
#
# [83467 rows x 7 columns]

# %%
target
# Out:
#              사고원인
# 0            산악기타
# 1      개인(급.만성)질환
# 2            일반조난
# 3            산악기타
# 4            산악기타
# 5            산악기타
# 6            일반조난
# 7            일반조난
# 8            일반조난
# 9            실족추락
# 10           실족추락
# 11           일반조난
# 12           실족추락
# 13     개인(급.만성)질환
# 14           산악기타
# 15           산악기타
# 16           일반조난
# 17           실족추락
# 18           산악기타
# 19           산악기타
# 20           실족추락
# 21           산악기타
# 22           산악기타
# 23           실족추락
# 24           실족추락
# 25           실족추락
# 26           산악기타
# 27           산악기타
# 28           산악기타
# 29           실족추락
# ...           ...
# 83437        기타산악
# 83438        개인질환
# 83439        일반조난
# 83440        기타산악
# 83441        개인질환
# 83442        기타산악
# 83443        기타산악
# 83444        기타산악
# 83445        기타산악
# 83446        일반조난
# 83447        기타산악
# 83448        기타산악
# 83449        실족추락
# 83450        기타산악
# 83451        기타산악
# 83452        기타산악
# 83453        실족추락
# 83454        기타산악
# 83455        실족추락
# 83456        개인질환
# 83457        기타산악
# 83458        기타산악
# 83459        기타산악
# 83460        실족추락
# 83461        기타산악
# 83462        기타산악
# 83463        실족추락
# 83464        개인질환
# 83465        기타산악
# 83466        기타산악
#
# [83467 rows x 1 columns]

# %%
## 레이블링 방법 1

target.replace({'개인(급.만성)질환':1}, inplace= True)
target.replace({'개인질환':1}, inplace= True)
target.replace({'고온환경질환':0}, inplace= True)
target.replace({'기타산악':1}, inplace= True)
target.replace({'낙석·낙빙':0}, inplace= True)
target.replace({'산악기타':2}, inplace= True)
target.replace({'실족추락':2}, inplace= True)
target.replace({'암벽등반':2}, inplace= True)
target.replace({'야생식물 섭취 중독':1}, inplace= True)
target.replace({'일반조난':2}, inplace= True)
target.replace({'저체온증':0}, inplace= True)
target.replace({'탈진·탈수':0}, inplace= True)
target.replace({'자살기도(산악)':1}, inplace= True)

# %%
## 레이블링 방법 1

target.replace({'개인(급.만성)질환':2}, inplace= True)
target.replace({'개인질환':2}, inplace= True)
target.replace({'고온환경질환':1}, inplace= True)
target.replace({'기타산악':2}, inplace= True)
target.replace({'낙석·낙빙':1}, inplace= True)
target.replace({'산악기타':3}, inplace= True)
target.replace({'실족추락':3}, inplace= True)
target.replace({'암벽등반':3}, inplace= True)
target.replace({'야생식물 섭취 중독':2}, inplace= True)
target.replace({'일반조난':3}, inplace= True)
target.replace({'저체온증':1}, inplace= True)
target.replace({'탈진·탈수':1}, inplace= True)
target.replace({'자살기도(산악)':2}, inplace= True)

# %%
## 레이블링 방법 2

target.replace({'개인(급.만성)질환':1}, inplace= True)
target.replace({'개인질환':2}, inplace= True)
target.replace({'고온환경질환':3}, inplace= True)
target.replace({'기타산악':4}, inplace= True)
target.replace({'낙석·낙빙':5}, inplace= True)
target.replace({'산악기타':6}, inplace= True)
target.replace({'실족추락':7}, inplace= True)
target.replace({'암벽등반':8}, inplace= True)
target.replace({'야생식물 섭취 중독':9}, inplace= True)
target.replace({'일반조난':10}, inplace= True)
target.replace({'저체온증':11}, inplace= True)
target.replace({'탈진·탈수':12}, inplace= True)
target.replace({'자살기도(산악)':13}, inplace= True)

# %%
## 레이블링 방법 3

target.replace({1:2}, inplace= True)
target.replace({2:2}, inplace= True)
target.replace({3:2}, inplace= True)
target.replace({4:1}, inplace= True)
target.replace({5:3}, inplace= True)
target.replace({6:3}, inplace= True)
target.replace({7:5}, inplace= True)
target.replace({8:5}, inplace= True)
target.replace({9:1}, inplace= True)
target.replace({10:4}, inplace= True)
target.replace({11:2}, inplace= True)
target.replace({12:2}, inplace= True)
target.replace({13:1}, inplace= True)

# %%
target
# Out:
#        사고원인
# 0         2
# 1         1
# 2         2
# 3         2
# 4         2
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        2
# 12        2
# 13        1
# 14        2
# 15        2
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        2
# 22        2
# 23        2
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
# ...     ...
# 83437     1
# 83438     1
# 83439     2
# 83440     1
# 83441     1
# 83442     1
# 83443     1
# 83444     1
# 83445     1
# 83446     2
# 83447     1
# 83448     1
# 83449     2
# 83450     1
# 83451     1
# 83452     1
# 83453     2
# 83454     1
# 83455     2
# 83456     1
# 83457     1
# 83458     1
# 83459     1
# 83460     2
# 83461     1
# 83462     1
# 83463     2
# 83464     1
# 83465     1
# 83466     1
#
# [83467 rows x 1 columns]

# %%
target
# Out:
#        사고원인
# 0         3
# 1         2
# 2         4
# 3         3
# 4         3
# 5         3
# 6         4
# 7         4
# 8         4
# 9         5
# 10        5
# 11        4
# 12        5
# 13        2
# 14        3
# 15        3
# 16        4
# 17        5
# 18        3
# 19        3
# 20        5
# 21        3
# 22        3
# 23        5
# 24        5
# 25        5
# 26        3
# 27        3
# 28        3
# 29        5
# ...     ...
# 83437     1
# 83438     2
# 83439     4
# 83440     1
# 83441     2
# 83442     1
# 83443     1
# 83444     1
# 83445     1
# 83446     4
# 83447     1
# 83448     1
# 83449     5
# 83450     1
# 83451     1
# 83452     1
# 83453     5
# 83454     1
# 83455     5
# 83456     2
# 83457     1
# 83458     1
# 83459     1
# 83460     5
# 83461     1
# 83462     1
# 83463     5
# 83464     2
# 83465     1
# 83466     1
#
# [83467 rows x 1 columns]

# %% [markdown]
# ## DUMMY

# %%
from sklearn.dummy import DummyClassifier
from sklearn.utils import check_X_y

# %%
dummy = DummyClassifier()

X_converted, y_converted = check_X_y(X=X_train, y= y_train)
X_converted_test, y_converted_test = check_X_y(X=X_test, y=y_test)
# Out:
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
dummy.fit(X=X_converted, y=y_converted)
dummy_pred = dummy.predict(X_converted_test)

# %%
dummy.score(X_test, dummy_pred)
# Out:
# 0.6650213255379307

# %% [markdown]
# ## KNN

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target, test_size = 0.25, stratify = target)

# %%
X_train.shape
# Out:
# (62600, 7)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
knn.predict(X_test)
# Out:
# array([3, 3, 3, ..., 3, 3, 3], dtype=int64)

# %%
knn.score(X_test, y_test)
# Out:
# 0.7569367901471222

# %% [markdown]
# ## Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()

# %%
nb.fit(abs(X_train), abs(y_train))
# Out:
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
nb.score(X_test, y_test)
# Out:
# 0.7787894762064503

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.score(X_test, y_test)
# Out:
# 0.7708822542770882

# %% [markdown]
# ## Neural Network

# %%
import tensorflow as tf

# %%
X_trainND = X_train.values
y_trainND = y_train.values
X_testND, y_testND = X_test.values, y_test.values

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import minmax_scale

# %%
X_scaled_train, y_scaled_train = minmax_scale(X_train), minmax_scale(y_train)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64.
#   """Entry point for launching an IPython kernel.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64 were all converted to float64.
#   """Entry point for launching an IPython kernel.

# %%
X_scaled_test, y_scaled_test = minmax_scale(X_test), minmax_scale(y_test)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int32, float64 were all converted to float64.
#   """Entry point for launching an IPython kernel.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64 were all converted to float64.
#   """Entry point for launching an IPython kernel.

# %%
def create_model():
    model = Sequential()
    model.add(Dense(512, activation=tf.nn.relu))
    model.add(Dropout(0,6))
    model.add(Dense(256, activation=tf.nn.relu))
    model.add(Dropout(0,4))
    model.add(Dense(128, activation=tf.nn.relu))
    model.add(Dropout(0,2))
    model.add(Dense(3,activation = tf.nn.softmax))
    model.compile(loss = "sparse_categorical_crossentropy", optimizer="adam",metrics=['accuracy'])
    return model

# %%
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.BatchNormalization(axis=1),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(5, activation=tf.nn.softmax)
])

# %%
model1.compile(optimizer='adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy']
              )

# %%
model2 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(),
    tf.keras.layers.BatchNormalization(axis=1),
    tf.keras.layers.Dense(512, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.6),
    tf.keras.layers.Dense(256, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(3, activation=tf.nn.softmax)
])
model2.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model2.fit(X_trainND, y_trainND, epochs=5, shuffle = True)
# Out:
# Epoch 1/5
# 62600/62600 [==============================] - 9s 139us/sample - loss: 0.5807 - acc: 0.7917
# Epoch 2/5
# 62600/62600 [==============================] - 8s 135us/sample - loss: 0.5674 - acc: 0.7920
# Epoch 3/5
# 62600/62600 [==============================] - 8s 135us/sample - loss: 0.5671 - acc: 0.7920
# Epoch 4/5
# 62600/62600 [==============================] - 9s 139us/sample - loss: 0.5655 - acc: 0.7920
# Epoch 5/5
# 62600/62600 [==============================] - 9s 150us/sample - loss: 0.5652 - acc: 0.7920

# %%
model2.evaluate(X_testND, y_testND)
# Out:
# 20867/20867 [==============================] - 1s 61us/sample - loss: 0.5622 - acc: 0.7920
# [0.5622255742027173, 0.79196817]

# %%
X_testND.shape
# Out:
# (20867, 7)

# %%
model2.predict_proba(X_testND)
# Out:
# array([[0.01448793, 0.18297777, 0.80253434],
#        [0.01514853, 0.17412403, 0.8107274 ],
#        [0.03045215, 0.19855677, 0.7709911 ],
#        ...,
#        [0.01974351, 0.18135531, 0.7989012 ],
#        [0.01466107, 0.19557437, 0.7897645 ],
#        [0.01281919, 0.18724826, 0.79993254]], dtype=float32)

# %%
predict_probability = pd.DataFrame(model2.predict_proba(X_testND), columns=['날씨에의한사고', '산악사고가아닌사고', '산악사고'])

# %%
predict_probability
# Out:
#         날씨에의한사고  산악사고가아닌사고      산악사고
# 0      0.014488   0.182978  0.802534
# 1      0.015149   0.174124  0.810727
# 2      0.030452   0.198557  0.770991
# 3      0.016543   0.184517  0.798940
# 4      0.012918   0.168335  0.818747
# 5      0.016126   0.193225  0.790649
# 6      0.015321   0.171878  0.812801
# 7      0.015086   0.180054  0.804860
# 8      0.032988   0.198753  0.768258
# 9      0.015299   0.191582  0.793119
# 10     0.007105   0.155260  0.837635
# 11     0.016055   0.184697  0.799248
# 12     0.015521   0.182627  0.801852
# 13     0.007543   0.176767  0.815690
# 14     0.013491   0.175350  0.811160
# 15     0.015118   0.166903  0.817979
# 16     0.014885   0.171230  0.813885
# 17     0.010719   0.162343  0.826938
# 18     0.013655   0.193015  0.793330
# 19     0.016215   0.209725  0.774060
# 20     0.020208   0.211335  0.768457
# 21     0.016108   0.179147  0.804744
# 22     0.014760   0.183756  0.801484
# 23     0.011686   0.167699  0.820616
# 24     0.013289   0.166884  0.819827
# 25     0.011462   0.174081  0.814457
# 26     0.014645   0.183459  0.801896
# 27     0.014157   0.184127  0.801716
# 28     0.012952   0.182847  0.804201
# 29     0.015749   0.178836  0.805415
# ...         ...        ...       ...
# 20837  0.008958   0.163670  0.827372
# 20838  0.013284   0.178752  0.807963
# 20839  0.012096   0.162025  0.825878
# 20840  0.015431   0.176359  0.808210
# 20841  0.015584   0.175805  0.808611
# 20842  0.009219   0.153942  0.836839
# 20843  0.018927   0.206520  0.774553
# 20844  0.009786   0.184508  0.805706
# 20845  0.016341   0.179894  0.803765
# 20846  0.014820   0.193987  0.791193
# 20847  0.011667   0.159795  0.828538
# 20848  0.011627   0.165312  0.823062
# 20849  0.014944   0.184687  0.800369
# 20850  0.015136   0.168857  0.816006
# 20851  0.013471   0.165767  0.820762
# 20852  0.014002   0.166994  0.819003
# 20853  0.011870   0.185412  0.802717
# 20854  0.007785   0.178322  0.813892
# 20855  0.013177   0.166250  0.820574
# 20856  0.012989   0.167629  0.819383
# 20857  0.014294   0.171735  0.813971
# 20858  0.008867   0.164225  0.826909
# 20859  0.015389   0.192093  0.792519
# 20860  0.016601   0.173000  0.810399
# 20861  0.006784   0.162995  0.830221
# 20862  0.013091   0.167257  0.819652
# 20863  0.012950   0.187462  0.799588
# 20864  0.019744   0.181355  0.798901
# 20865  0.014661   0.195574  0.789765
# 20866  0.012819   0.187248  0.799933
#
# [20867 rows x 3 columns]

# %% [markdown]
# ### 지수화

# %%
value = pd.DataFrame((predict_probability['날씨에의한사고'] + predict_probability['산악사고']) / predict_probability['산악사고가아닌사고'])

# %%
value1 = predict_probability['날씨에의한사고'] / predict_probability['산악사고가아닌사고']

# %%
value2 = predict_probability['산악사고'] / predict_probability['산악사고가아닌사고']

# %%
min_max1 =(value1-value1.min()) / (value1.max() - value1.min())

# %%
min_max2 =(value2-value2.min()) / (value2.max() - value2.min())

# %%
value.max()
# Out:
# 0    94.358215
# dtype: float32

# %%
value.min()
# Out:
# 0    3.392908
# dtype: float32

# %%
sns.distplot(min_max2)

# %%
sns.distplot(min_max1)

# %%
min_mix = (value-value.min()) / (value.max() - value.min())

# %%
model2.predict(real_test)
# Out:
# array([[0.01097752, 0.18501095, 0.80401146],
#        [0.01267606, 0.19086981, 0.7964541 ],
#        [0.00262633, 0.12047397, 0.87689966]], dtype=float32)

# %%
temp = minmax_scale(value)
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype float32 were all converted to float64.
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler(value, with_mean=0, with_std=0)

# %%
valueND = value.to_numpy()

# %%
value_mean = value.mean()

# %%
value_mean = value_mean.values[0]

# %%
value_std = value.std()

# %%
value_std = value_std.values[0]

# %%
scaled_value = (value - value_mean) / value_std

# %%
scaled_value
# Out:
#               0
# 0     -0.156883
# 1      0.092896
# 2     -0.542311
# 3     -0.197866
# 4      0.270408
# 5     -0.417407
# 6      0.160345
# 7     -0.077119
# 8     -0.546788
# 9     -0.377507
# 10     0.720106
# 11    -0.202618
# 12    -0.147450
# 13     0.015707
# 14     0.056814
# 15     0.316239
# 16     0.180142
# 17     0.467513
# 18    -0.412330
# 19    -0.783372
# 20    -0.816035
# 21    -0.051846
# 22    -0.177685
# 23     0.290679
# 24     0.316838
# 25     0.094179
# 26    -0.169770
# 27    -0.187535
# 28    -0.153368
# 29    -0.043115
# ...         ...
# 20837  0.422630
# 20838 -0.040767
# 20839  0.478362
# 20840  0.027481
# 20841  0.043532
# 20842  0.769651
# 20843 -0.716857
# 20844 -0.197631
# 20845 -0.072675
# 20846 -0.435682
# 20847  0.555799
# 20848  0.368072
# 20849 -0.202357
# 20850  0.253905
# 20851  0.353148
# 20852  0.313288
# 20853 -0.221385
# 20854 -0.028634
# 20855  0.337399
# 20856  0.292919
# 20857  0.164711
# 20858  0.404057
# 20859 -0.389974
# 20860  0.126432
# 20861  0.445366
# 20862  0.304846
# 20863 -0.274398
# 20864 -0.112936
# 20865 -0.473278
# 20866 -0.268917
#
# [20867 rows x 1 columns]

# %%
scaled_value.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018321A0B470>]],
#       dtype=object)

# %%
model2.predict(real_test)

0.01097752/0.80401146, 0.18501095/0.80401146
0.01097752/0.80401146, 0.18501095/0.80401146
0.01097752/0.80401146, 0.18501095/0.80401146
# Out:
# (0.013653437228369853, 0.23010984196668044)

# %%
value1.quantile(0.6)
# Out:
# 0.0834925040602684

# %%
value2.quantile(0.6)
# Out:
# 4.617175960540772

# %%
import seaborn as sns
import matplotlib.pylabs as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-783-8e4471fdb023> in <module>
#       1 import seaborn as sns
# ----> 2 import matplotlib.pylabs as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pylabs'

# %%
import pylab as plt

# %%
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-781-5f8bf4a93294> in <module>
# ----> 1 plt.clf()
#
# AttributeError: module 'matplotlib' has no attribute 'clf'

# %%
sns.distplot(scaled_value)
plt.xlim(-5, 5)
# Out:
# (-5, 5)

# %%
real_test = pd.DataFrame(np.array([[-1,0,2.7,25,-18.5,0,3.7], [-3.2,-.0,0.9,33,-17.2,0,2.3], [17.5,11.5,3.8,95,16.6,0,18.7]]) )

# %%
model2.predict(real_test)
# Out:
# array([[0.01097752, 0.18501095, 0.80401146],
#        [0.01267606, 0.19086981, 0.7964541 ],
#        [0.00262633, 0.12047397, 0.87689966]], dtype=float32)

# %%
def scaling:

# %%
real_test
# Out:
#      0    1    2     3     4    5    6
# 0 -1.0  0.0  2.7  25.0 -18.5  0.0  3.7
# 1 -3.2 -0.0  0.9  33.0 -17.2  0.0  2.3

# %%
df
# Out:
#        기온(°C)  강수량(mm)  풍속(m/s)  습도(%)
# 83453    -4.5      0.0      0.8   31.0      -19.1     0.0      -0.5
# 83454    -4.4      0.0      1.1   24.0      -21.9     0.0       2.9
# 83455    -4.4      0.0      1.1   24.0      -21.9     0.0       2.9
# 83456    -3.2      0.0      1.4   26.0      -20.0     0.0       6.5
# 83457    -3.2      0.0      1.4   26.0      -20.0     0.0       6.5
# 83458    -2.9      0.0      2.3   27.0      -19.3     0.0       2.0
# 83459    -2.9      0.0      2.3   27.0      -19.3     0.0       2.0
# 83460    -3.1      0.0      0.9   23.0      -21.3     0.0       0.2
# 83461    -2.6      0.0      1.2   27.0      -19.0     0.0      -2.4
# 83462    -2.2      0.0      0.7   29.0      -17.8     0.0       1.6
# 83463    -2.3      0.0      0.8   26.0      -19.2     0.0      -1.8
# 83464    -1.0      0.0      1.7   24.0      -19.0     0.0       2.1
# 83465    -1.6      0.0      0.7   34.0      -15.4     0.0      -1.3
# 83466     1.3      0.0      3.9   29.0      -14.8     0.0      -0.3
#
# [83467 rows x 7 columns]

# %%
# Out:
# StandardScaler(copy=              0
# 0      4.465145
# 1      4.743032
# 2      4.036343
# 3      4.419550
# 4      4.940521
# 5      4.175303
# 6      4.818072
# 7      4.553885
# 8      4.031362
# 9      4.219694
# 10     5.440825
# 11     4.414264
# 12     4.475639
# 13     4.657158
# 14     4.702890
# 15     4.991509
# 16     4.840096
# 17     ...  4.978834
# 20863  4.334406
# 20864  4.514038
# 20865  4.113144
# 20866  4.340503
#
# [20867 rows x 1 columns],
#         with_mean=0, with_std=0)

# %%
pd.DataFrame(value_std.data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-724-125fc5dda7f1> in <module>
# ----> 1 pd.DataFrame(value_std.data)
#
# AttributeError: 'StandardScaler' object has no attribute 'data'

# %%
pd.DataFrame(temp).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000183125CE3C8>]],
#       dtype=object)

# %%
min_mix
# Out:
#               0
# 0      0.011787
# 1      0.014842
# 2      0.007073
# 3      0.011286
# 4      0.017013
# 5      0.008601
# 6      0.015667
# 7      0.012763
# 8      0.007019
# 9      0.009089
# 10     0.022513
# 11     0.011228
# 12     0.011903
# 13     0.013898
# 14     0.014401
# 15     0.017574
# 16     0.015909
# 17     0.019424
# 18     0.008663
# 19     0.004125
# 20     0.003726
# 21     0.013072
# 22     0.011533
# 23     0.017261
# 24     0.017581
# 25     0.014858
# 26     0.011630
# 27     0.011412
# 28     0.011830
# 29     0.013179
# ...         ...
# 20837  0.018875
# 20838  0.013207
# 20839  0.019557
# 20840  0.014042
# 20841  0.014238
# 20842  0.023119
# 20843  0.004939
# 20844  0.011289
# 20845  0.012817
# 20846  0.008378
# 20847  0.020504
# 20848  0.018208
# 20849  0.011231
# 20850  0.016811
# 20851  0.018025
# 20852  0.017538
# 20853  0.010998
# 20854  0.013356
# 20855  0.017833
# 20856  0.017289
# 20857  0.015721
# 20858  0.018648
# 20859  0.008937
# 20860  0.015252
# 20861  0.019153
# 20862  0.017434
# 20863  0.010350
# 20864  0.012325
# 20865  0.007918
# 20866  0.010417
#
# [20867 rows x 1 columns]

# %%
min_mix.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000183205D94A8>]],
#       dtype=object)

# %%
last = min_mix * 100

# %%
last
# Out:
#               0
# 0      1.178732
# 1      1.484219
# 2      0.707341
# 3      1.128609
# 4      1.701322
# 5      0.860102
# 6      1.566711
# 7      1.276286
# 8      0.701865
# 9      0.908902
# 10     2.251317
# 11     1.122797
# 12     1.190268
# 13     1.389815
# 14     1.440089
# 15     1.757375
# 16     1.590923
# 17     1.942387
# 18     0.866312
# 19     0.412516
# 20     0.372568
# 21     1.307196
# 22     1.153291
# 23     1.726114
# 24     1.758108
# 25     1.485788
# 26     1.162971
# 27     1.141244
# 28     1.183031
# 29     1.317874
# ...         ...
# 20837  1.887495
# 20838  1.320746
# 20839  1.955657
# 20840  1.404215
# 20841  1.423845
# 20842  2.311911
# 20843  0.493866
# 20844  1.128896
# 20845  1.281720
# 20846  0.837752
# 20847  2.050364
# 20848  1.820768
# 20849  1.123116
# 20850  1.681139
# 20851  1.802516
# 20852  1.753766
# 20853  1.099844
# 20854  1.335585
# 20855  1.783254
# 20856  1.728854
# 20857  1.572052
# 20858  1.864778
# 20859  0.893654
# 20860  1.525235
# 20861  1.915302
# 20862  1.743441
# 20863  1.035008
# 20864  1.232480
# 20865  0.791770
# 20866  1.041710
#
# [20867 rows x 1 columns]

# %%
last.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001831D482390>]],
#       dtype=object)

# %% [markdown]
# ## XGBOOST

# %%
import xgboost as xgb
from matplotlib import pyplot

# %%
from xgboost import XGBClassifier

# %%
param = {'max_depth':4, 'eta':1, 'silent':1, 'objective':'binary:logistic'}

# %%
watchlist = [(, 'eval'), (dtrain, 'train')]
# Out:
#   File "<ipython-input-433-d207d20f9231>", line 1
#     watchlist = [(, 'eval'), (dtrain, 'train')]
#                   ^
# SyntaxError: invalid syntax

# %%
bst = xgb.train(param, df, 1, watchlist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-434-28aae4bdaeec> in <module>
# ----> 1 bst = xgb.train(param, df, 1, watchlist)
#
# NameError: name 'watchlist' is not defined

# %%
xgb = XGBClassifier()

# %%
temp.
# Out:
#   File "<ipython-input-436-2110fd6e3163>", line 1
#     temp.
#          ^
# SyntaxError: invalid syntax

# %%
pyplot.bar(range(len(temp.feature_importances_)), temp.feature_importances_)
# Out:
# <BarContainer object of 7 artists>

# %%
temp = xgb.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred = xgb.predict(X_test)

# %%
xgb.score(X_test, y_test)
# Out:
# 0.7917764891934633

# %%
predictions = [round(value) for value in y_pred]

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, predictions)

# %%
print("Accuracy: %.2f%%" % (accuracy*100.0))
# Out:
# Accuracy: 79.18%

# %% [markdown]
# ### GRID search in XGBoost

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_test1 = { 'max_depth' : range(3,10,2), 'min-chile_weight':range(1,6,2)}

# %%
gsearch1 = GridSearchCV(estimator = XGBClassifier( learning_rate =0.1, n_estimators=140, max_depth=5,
 min_child_weight=1, gamma=0, subsample=0.8, colsample_bytree=0.8,
 objective= 'multi:softprob', nthread=4, scale_pos_weight=1, seed=27), 
 param_grid = param_test1, scoring='accuracy',n_jobs=4,iid=False, cv=5)

gsearch1.fit(X_train, y_train)
gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# C:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\anaconda\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-197-ea341179d53d> in <module>
#       5
#       6 gsearch1.fit(X_train, y_train)
# ----> 7 gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
#
# AttributeError: 'GridSearchCV' object has no attribute 'grid_scores_'

# %%
gsearch1.

# %%
gsearch1.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.8, gamma=0,
#        learning_rate=0.1, max_delta_step=0, max_depth=5,
#        min-chile_weight=1, min_child_weight=1, missing=None,
#        n_estimators=140, n_jobs=1, nthread=4, objective='multi:softprob',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=27, silent=None, subsample=0.8, verbosity=1)

# %%
gsearch1.best_score_
# Out:
# 0.7921086176963139

# %%
gsearch1.score(X_test, y_test)
# Out:
# 0.7925432501078258

# %%
pd.to_pickle(gsearch1, 'gridserachxgboost.pickle')

# %%
gsearch1.predict(X_test)
# Out:
# array([3, 3, 3, ..., 3, 3, 3], dtype=int64)

# %%
temp = pd.DataFrame(gsearch1.predict_proba(X_test), columns=['a','b','c'])

# %%
temp['d'] = (temp["a"] + temp['c']) / temp['b']

# %%
temp['d'].max()
# Out:
# 40.14031

# %%
temp['d'].min()
# Out:
# 0.58659697

# %%
temp['d'].mean()
# Out:
# 4.530893802642822

# %%
gsearch1.predict_proba(X_test)[][:]
# Out:
# array([0.00663583, 0.15571463, 0.8376496 ], dtype=float32)

# %%
model1.predict_proba(X_test)
# Out:
# array([[4.47090720e-09, 1.21569615e-02, 2.22669750e-01, 7.65173018e-01,
#         2.61461565e-07, 1.41398648e-09],
#        [4.84949442e-06, 4.50500250e-02, 2.54631639e-01, 7.00235605e-01,
#         7.53225904e-05, 2.67830865e-06],
#        [5.16497636e-08, 1.79753881e-02, 2.12384000e-01, 7.69636333e-01,
#         4.25683947e-06, 1.67466503e-08],
#        ...,
#        [6.08561246e-09, 1.30470712e-02, 1.78440094e-01, 8.08510423e-01,
#         2.39893166e-06, 1.99448502e-09],
#        [1.25806983e-08, 1.46458466e-02, 1.85648546e-01, 7.99702466e-01,
#         3.10264909e-06, 4.22305035e-09],
#        [9.95940574e-09, 1.44248353e-02, 1.83311716e-01, 8.02259922e-01,
#         3.49103129e-06, 3.47420359e-09]], dtype=float32)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import LinearSVC, SVC

# %%
svc = SVC(kernel='rbf')

# %%
svc.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\anaconda\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
svc.score(X_test, y_test)
# Out:
# 0.7923994824363828

# %% [markdown]
# ## logistic Classifier

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
lr = LogisticRegressionCV()

# %%
lr.fit(X_train, y_train)
# Out:
# C:\anaconda\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\anaconda\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\anaconda\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# LogisticRegressionCV(Cs=10, class_weight=None, cv='warn', dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=100,
#            multi_class='warn', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='lbfgs',
#            tol=0.0001, verbose=0)

# %%
lr.score(X_test, y_test)
# Out:
# 0.791968179422054

# %%
lr.class_weight

# %%
lr.coef_
# Out:
# array([[ 0.0026345 ,  0.00083977, -0.01947545,  0.00222588,  0.00289239,
#         -0.00046743,  0.02135024],
#        [-0.02708693, -0.01093542, -0.03823372,  0.00085186, -0.00324597,
#         -0.02009274,  0.02647013],
#        [ 0.02652294,  0.00936564,  0.04504451, -0.00097373,  0.00292846,
#          0.01865134, -0.0278707 ]])
