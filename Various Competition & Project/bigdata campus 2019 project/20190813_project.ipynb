# %%
import numpy as np
import pandas as pd

# %%
year2010 = pd.read_csv('2010년시간.csv',engine= 'python')
year2011 = pd.read_csv('2011년시간.csv',engine= 'python')
year2012 = pd.read_csv('2012년시간.csv',engine= 'python')
year2013 = pd.read_csv('2013년시간.csv',engine= 'python')
year2014 = pd.read_csv('2014년시간.csv',engine= 'python')
year2015 = pd.read_csv('2015년시간.csv',engine= 'python')
year2016 = pd.read_csv('2016년시간.csv',engine= 'python')
year2017 = pd.read_csv('2017년시간.csv',engine= 'python')
year2018 = pd.read_csv('2018년시간.csv',engine= 'python')
year2019 = pd.read_csv('2019년시간.csv',engine= 'python')
cc = pd.read_excel('cccc.xlsx')
##2010~2019년 파일을 받아온다.

# %%
(year2010.shape,cc.shape, year2011.shape,year2012.shape,year2013.shape,year2014.shape, year2015.shape, year2016.shape, year2017.shape, year2018.shape)
## 각각 shape 확인
# Out:
# ((483341, 36),
#  (2184, 36),
#  (831995, 36),
#  (831625, 36),
#  (827726, 36),
#  (819535, 36),
#  (820219, 36),
#  (807872, 36),
#  (812439, 36),
#  (810640, 36))

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# cc         DataFrame           지점                <...>n[2184 rows x 36 columns]
# np         module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# year2010   DataFrame             지점              <...>483341 rows x 36 columns]
# year2011   DataFrame             지점              <...>831995 rows x 36 columns]
# year2012   DataFrame             지점              <...>831625 rows x 36 columns]
# year2013   DataFrame             지점              <...>827726 rows x 36 columns]
# year2014   DataFrame             지점              <...>819535 rows x 36 columns]
# year2015   DataFrame             지점              <...>820219 rows x 36 columns]
# year2016   DataFrame             지점              <...>807872 rows x 36 columns]
# year2017   DataFrame             지점              <...>812439 rows x 36 columns]
# ...

# %%
whos
# Out:
# Variable      Type         Data/Info
# ------------------------------------
# cc            DataFrame           지점                <...>n[2184 rows x 36 columns]
# cols          list         n=12
# np            module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd            module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# raw_weather   DataFrame    <object with id 1496827252688 (str() failed)>
# temp          DataFrame                        신고일시2<...>[84496 rows x 47 columns]
# weather       DataFrame    <object with id 1496932209104 (str() failed)>
# 위도경도          DataFrame                        신고일시2<...>[84325 rows x 12 columns]
# 위도경도2         DataFrame                        신고일시2<...>[84310 rows x 13 columns]

# %%
weather = pd.concat([year2010, cc, year2011, year2012, year2013, year2014, year2015, year2016, year2017, year2018, year2019])
## 데이터를 weather에 합친다
weather.shape
# Out:
# (7808258, 36)

# %%
raw_weather=weather.copy()

# %%
raw_weather.shape , weather.shape
# Out:
# ((7808258, 36), (7808258, 36))

# %%
weather.sample(10)
# Out:
#          지점                일시  기온(°C)  기온 QC플래그  강수량(mm)  강수량 QC플래그  풍속(m/s)  \
# 281345  162  2011-02-12 20:00    -0.2       0.0      NaN        NaN      2.0
# 199812  136  2010-11-13 14:00    14.3       0.0      NaN        NaN      1.0
# 289065  232  2019-06-23 04:00    15.0       NaN      NaN        NaN      0.0
# 260123  155  2013-09-11 21:00    25.4       0.0      NaN        NaN      1.4
# 105376  114  2015-01-13 00:00    -5.1       0.0      NaN        NaN      0.2
# 663780  263  2014-10-14 08:00    10.2       0.0      NaN        NaN      0.1
# 201931  136  2018-01-21 08:00    -5.4       0.0      NaN        NaN      0.4
# 397477  189  2018-05-21 09:00    19.0       0.0      NaN        NaN      4.1
# 98126   112  2015-03-16 22:00     8.8       0.0      NaN        NaN      0.7
# 587892  254  2013-11-14 03:00    -1.3       0.0      NaN        NaN      0.6
#
#         풍속 QC플래그  풍향(16방위)  풍향 QC플래그  ...  최저운고(100m )  시정(10m)  지면상태(지면상태코드)  \
# ...

# %%
위도경도 = pd.read_excel('data_최종.xlsx')

# %%
위도경도['신고일시2'] = 위도경도['신고일시'].dt.strftime('%Y-%m-%d %H:00')

# %%
위도경도['신고일시2'] = pd.to_datetime(위도경도['신고일시2'])

# %%
위도경도.dtypes
# Out:
# Unnamed: 0               int64
# Unnamed: 0.1             int64
# 신고일시            datetime64[ns]
# 주소                      object
# 사고원인                    object
# 구조상태                    object
# 처리결과                    object
# mountain                object
# 인접산                     object
# 산주소                     object
# 산id                      int64
# 위도                     float64
# 경도                     float64
# 신고일시2           datetime64[ns]
# dtype: object

# %%
cols = 위도경도.columns.tolist()
cols = cols[2:]
cols = cols[-1:] + cols[:-1]
cols
# Out:
# ['신고일시2',
#  '신고일시',
#  '주소',
#  '사고원인',
#  '구조상태',
#  '처리결과',
#  'mountain',
#  '인접산',
#  '산주소',
#  '산id',
#  '위도',
#  '경도']

# %%
위도경도 = 위도경도[cols]

# %%
위도경도.dtypes
# Out:
# 신고일시2       datetime64[ns]
# 신고일시        datetime64[ns]
# 주소                  object
# 사고원인                object
# 구조상태                object
# 처리결과                object
# mountain            object
# 인접산                 object
# 산주소                 object
# 산id                  int64
# 위도                 float64
# 경도                 float64
# dtype: object

# %%
위도경도.to_excel('위도경도.xlsx')

# %%
위도경도
# Out:
#                     신고일시2                신고일시                주소        사고원인  \
# 0     2010-01-01 07:00:00 2010-01-01 07:49:00        강원도 태백시 혈동        산악기타
# 1     2010-01-01 11:00:00 2010-01-01 11:16:00        강원도 태백시 혈동  개인(급.만성)질환
# 2     2010-01-01 11:00:00 2010-01-01 11:31:00       강원도 태백시 소도동        일반조난
# 3     2010-01-02 07:00:00 2010-01-02 07:44:00       강원도 태백시 황지동        산악기타
# 4     2010-01-02 11:00:00 2010-01-02 11:34:00       강원도 태백시 소도동        산악기타
# 5     2010-01-02 16:00:00 2010-01-02 16:37:00       강원도 태백시 소도동        산악기타
# 6     2010-01-01 00:00:00 2010-01-01 00:12:00  전라북도 남원시 운봉읍 공안리        일반조난
# 7     2010-01-01 05:00:00 2010-01-01 05:43:00  전라남도 진도군 진도읍 남동리        일반조난
# 8     2010-01-01 05:00:00 2010-01-01 05:43:00  전라남도 진도군 진도읍 남동리        일반조난
# 9     2010-01-01 06:00:00 2010-01-01 06:25:00     서울특별시 관악구 봉천동        실족추락
# 10    2010-01-01 06:00:00 2010-01-01 06:31:00       경기도 광명시 하안동        실족추락
# ...

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# cc         DataFrame           지점                <...>n[2184 rows x 36 columns]
# cols       list         n=12
# np         module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# weather    DataFrame             지점              <...>808258 rows x 36 columns]
# year2010   DataFrame             지점              <...>483341 rows x 36 columns]
# year2011   DataFrame             지점              <...>831995 rows x 36 columns]
# year2012   DataFrame             지점              <...>831625 rows x 36 columns]
# year2013   DataFrame             지점              <...>827726 rows x 36 columns]
# year2014   DataFrame             지점              <...>819535 rows x 36 columns]
# year2015   DataFrame             지점              <...>820219 rows x 36 columns]
# ...

# %%
del year2010, year2011,year2012,year2013,year2014,year2015,year2016,year2017,year2018,year2019

# %%
whos
# Out:
# Variable   Type         Data/Info
# ---------------------------------
# cc         DataFrame           지점                <...>n[2184 rows x 36 columns]
# cols       list         n=12
# np         module       <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# pd         module       <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# weather    DataFrame             지점              <...>808258 rows x 36 columns]
# 위도경도       DataFrame                        신고일시2<...>[84325 rows x 12 columns]

# %%
위도경도2 = pd.read_excel('위도경도2.xlsx')

# %%
weather.columns
# Out:
# Index(['지점', '일시', '기온(°C)', '기온 QC플래그', '강수량(mm)', '강수량 QC플래그', '풍속(m/s)',
#        '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그', '습도(%)', '습도 QC플래그', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그', '해면기압(hPa)', '해면기압 QC플래그',
#        '일조(hr)', '일조 QC플래그', '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)',
#        '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)',
#        '현상번호(국내식)', '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)', '10cm 지중온도(°C)',
#        '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
weather['지점'] = weather['지점'].replace(90, '속초')
weather['지점'] = weather['지점'].replace(116, '관악산')
weather['지점'] = weather['지점'].replace(108, '서울')
weather['지점'] = weather['지점'].replace(159, '부산')
weather['지점'] = weather['지점'].replace(143, '대구')
weather['지점'] = weather['지점'].replace(176, '대구(기)')
weather['지점'] = weather['지점'].replace(201, '강화')
weather['지점'] = weather['지점'].replace(102, '백령도')
weather['지점'] = weather['지점'].replace(112, '인천')
weather['지점'] = weather['지점'].replace(156, '광주')
weather['지점'] = weather['지점'].replace(133, '대전')
weather['지점'] = weather['지점'].replace(152, '울산')
weather['지점'] = weather['지점'].replace(98, '동두천')
weather['지점'] = weather['지점'].replace(119, '수원')
weather['지점'] = weather['지점'].replace(202, '양평')
weather['지점'] = weather['지점'].replace(203, '이천')
weather['지점'] = weather['지점'].replace(99, '파주')
weather['지점'] = weather['지점'].replace(105, '강릉')
weather['지점'] = weather['지점'].replace(100, '대관령')
weather['지점'] = weather['지점'].replace(106, '동해')
weather['지점'] = weather['지점'].replace(104, '북강릉')
weather['지점'] = weather['지점'].replace(93, '북춘천')
weather['지점'] = weather['지점'].replace(214, '삼척')
weather['지점'] = weather['지점'].replace(90, '속초')
weather['지점'] = weather['지점'].replace(121, '영월')
weather['지점'] = weather['지점'].replace(114, '원주')
weather['지점'] = weather['지점'].replace(211, '인제')
weather['지점'] = weather['지점'].replace(217, '정선')
weather['지점'] = weather['지점'].replace(95, '철원')
weather['지점'] = weather['지점'].replace(101, '춘천')
weather['지점'] = weather['지점'].replace(216, '태백')
weather['지점'] = weather['지점'].replace(212, '홍천')
weather['지점'] = weather['지점'].replace(226, '보은')
weather['지점'] = weather['지점'].replace(221, '제천')
weather['지점'] = weather['지점'].replace(131, '청주')
weather['지점'] = weather['지점'].replace(135, '추풍령')
weather['지점'] = weather['지점'].replace(127, '충주')
weather['지점'] = weather['지점'].replace(238, '금산')
weather['지점'] = weather['지점'].replace(235, '보령')
weather['지점'] = weather['지점'].replace(236, '부여')
weather['지점'] = weather['지점'].replace(129, '서산')
weather['지점'] = weather['지점'].replace(232, '천안')
weather['지점'] = weather['지점'].replace(177, '홍성')
weather['지점'] = weather['지점'].replace(172, '고창')
weather['지점'] = weather['지점'].replace(251, '고창군')
weather['지점'] = weather['지점'].replace(140, '군산')
weather['지점'] = weather['지점'].replace(247, '남원')
weather['지점'] = weather['지점'].replace(243, '부안')
weather['지점'] = weather['지점'].replace(254, '순창군')
weather['지점'] = weather['지점'].replace(244, '임실')
weather['지점'] = weather['지점'].replace(248, '장수')
weather['지점'] = weather['지점'].replace(146, '전주')
weather['지점'] = weather['지점'].replace(245, '정읍')
weather['지점'] = weather['지점'].replace(259, '강진군')
weather['지점'] = weather['지점'].replace(262, '고흥')
weather['지점'] = weather['지점'].replace(266, '광양시')
weather['지점'] = weather['지점'].replace(165, '목포')
weather['지점'] = weather['지점'].replace(164, '무안')
weather['지점'] = weather['지점'].replace(258, '보성군')
weather['지점'] = weather['지점'].replace(174, '순천')
weather['지점'] = weather['지점'].replace(168, '여수')
weather['지점'] = weather['지점'].replace(252, '영광군')
weather['지점'] = weather['지점'].replace(170, '완도')
weather['지점'] = weather['지점'].replace(260, '장흥')
weather['지점'] = weather['지점'].replace(256, '주암')
weather['지점'] = weather['지점'].replace(175, '진도')
weather['지점'] = weather['지점'].replace(261, '해남')
weather['지점'] = weather['지점'].replace(169, '흑산도')
weather['지점'] = weather['지점'].replace(283, '경주시')
weather['지점'] = weather['지점'].replace(279, '구미')
weather['지점'] = weather['지점'].replace(273, '문경')
weather['지점'] = weather['지점'].replace(271, '봉화')
weather['지점'] = weather['지점'].replace(137, '상주')
weather['지점'] = weather['지점'].replace(136, '안동')
weather['지점'] = weather['지점'].replace(277, '영덕')
weather['지점'] = weather['지점'].replace(272, '영주')
weather['지점'] = weather['지점'].replace(281, '영천')
weather['지점'] = weather['지점'].replace(115, '울릉도')
weather['지점'] = weather['지점'].replace(130, '울진')
weather['지점'] = weather['지점'].replace(278, '의성')
weather['지점'] = weather['지점'].replace(276, '청송군')
weather['지점'] = weather['지점'].replace(138, '포항')
weather['지점'] = weather['지점'].replace(294, '거제')
weather['지점'] = weather['지점'].replace(284, '거창')
weather['지점'] = weather['지점'].replace(253, '김해시')
weather['지점'] = weather['지점'].replace(295, '남해')
weather['지점'] = weather['지점'].replace(288, '밀양')
weather['지점'] = weather['지점'].replace(255, '북창원')
weather['지점'] = weather['지점'].replace(289, '산청')
weather['지점'] = weather['지점'].replace(257, '양산시')
weather['지점'] = weather['지점'].replace(263, '의령군')
weather['지점'] = weather['지점'].replace(192, '진주')
weather['지점'] = weather['지점'].replace(155, '창원')
weather['지점'] = weather['지점'].replace(162, '통영')
weather['지점'] = weather['지점'].replace(264, '함양군')
weather['지점'] = weather['지점'].replace(285, '합천')
weather['지점'] = weather['지점'].replace(185, '고산')
weather['지점'] = weather['지점'].replace(189, '서귀포')
weather['지점'] = weather['지점'].replace(188, '성산')
weather['지점'] = weather['지점'].replace(187, '성산')
weather['지점'] = weather['지점'].replace(265, '성산포')
weather['지점'] = weather['지점'].replace(184, '제주')
weather['지점'] =weather['지점'].replace('함양군', '함양')
weather['지점'] =weather['지점'].replace('영광군', '영광')
weather['지점'] =weather['지점'].replace('양산시', '양산')
weather['지점'] =weather['지점'].replace('보성군', '보성')
weather['지점'] =weather['지점'].replace('고창군', '고성')
weather['지점'] =weather['지점'].replace('광양시', '광양')
weather['지점'] =weather['지점'].replace('순창군', '순창')
weather['지점'] =weather['지점'].replace('의령군', '의령')
weather['지점'] =weather['지점'].replace('강진군', '강진')
weather['지점'] =weather['지점'].replace('김해시', '김해')
weather['지점'] =weather['지점'].replace('청송군', '청송')
weather['지점'] =weather['지점'].replace('울릉도', '울릉')
weather['지점'] =weather['지점'].replace('경주시', '경주')

# %%
weather.dtypes 
##일시가 object type으로 되어있다. 바꿔주자.
weather.rename(columns={'일시':'신고일시'}, inplace =True)
##그전에 일시를 신고일시로 통일 시켜주자
weather.columns
##신고일시로 잘들어간거 확인
# Out:
# Index(['지점', '신고일시', '기온(°C)', '기온 QC플래그', '강수량(mm)', '강수량 QC플래그', '풍속(m/s)',
#        '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그', '습도(%)', '습도 QC플래그', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그', '해면기압(hPa)', '해면기압 QC플래그',
#        '일조(hr)', '일조 QC플래그', '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)',
#        '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)',
#        '현상번호(국내식)', '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)', '10cm 지중온도(°C)',
#        '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
weather['신고일시'] = pd.to_datetime(weather['신고일시'])
## datetime 형식으로 바꿔주자.
weather.dtypes
# Out:
# 지점                       object
# 신고일시             datetime64[ns]
# 기온(°C)                  float64
# 기온 QC플래그                float64
# 강수량(mm)                 float64
# 강수량 QC플래그               float64
# 풍속(m/s)                 float64
# 풍속 QC플래그                float64
# 풍향(16방위)                float64
# 풍향 QC플래그                float64
# 습도(%)                   float64
# 습도 QC플래그                float64
# 증기압(hPa)                float64
# 이슬점온도(°C)               float64
# 현지기압(hPa)               float64
# 현지기압 QC플래그              float64
# 해면기압(hPa)               float64
# 해면기압 QC플래그              float64
# 일조(hr)                  float64
# 일조 QC플래그                float64
# 일사(MJ/m2)               float64
# 적설(cm)                  float64
# 3시간신적설(cm)              float64
# 전운량(10분위)               float64
# 중하층운량(10분위)             float64
# 운형(운형약어)                 object
# 최저운고(100m )             float64
# 시정(10m)                 float64
# 지면상태(지면상태코드)            float64
# ...

# %%
위도경도3 = pd.read_excel('위도경도3.xlsx')

# %%
위도경도3.dtypes
# Out:
# 신고일시2       datetime64[ns]
# 신고일시        datetime64[ns]
# 지점                  object
# 주소                  object
# 사고원인                object
# 구조상태                object
# 처리결과                object
# mountain            object
# 인접산                 object
# 산주소                 object
# 산id                  int64
# 위도                 float64
# 경도                 float64
# dtype: object

# %%
weather.dtypes
# Out:
# 지점                       object
# 신고일시             datetime64[ns]
# 기온(°C)                  float64
# 기온 QC플래그                float64
# 강수량(mm)                 float64
# 강수량 QC플래그               float64
# 풍속(m/s)                 float64
# 풍속 QC플래그                float64
# 풍향(16방위)                float64
# 풍향 QC플래그                float64
# 습도(%)                   float64
# 습도 QC플래그                float64
# 증기압(hPa)                float64
# 이슬점온도(°C)               float64
# 현지기압(hPa)               float64
# 현지기압 QC플래그              float64
# 해면기압(hPa)               float64
# 해면기압 QC플래그              float64
# 일조(hr)                  float64
# 일조 QC플래그                float64
# 일사(MJ/m2)               float64
# 적설(cm)                  float64
# 3시간신적설(cm)              float64
# 전운량(10분위)               float64
# 중하층운량(10분위)             float64
# 운형(운형약어)                 object
# 최저운고(100m )             float64
# 시정(10m)                 float64
# 지면상태(지면상태코드)            float64
# ...

# %%
set(위도경도3.신고일시2) - set(weather.신고일시)
# Out:
# set()

# %%
set(위도경도3.지점) - set(weather.지점)
# Out:
# set()

# %%
weather.rename(columns={'신고일시':'신고일시2'}, inplace=True)
weather.columns
# Out:
# Index(['지점', '신고일시2', '기온(°C)', '기온 QC플래그', '강수량(mm)', '강수량 QC플래그', '풍속(m/s)',
#        '풍속 QC플래그', '풍향(16방위)', '풍향 QC플래그', '습도(%)', '습도 QC플래그', '증기압(hPa)',
#        '이슬점온도(°C)', '현지기압(hPa)', '현지기압 QC플래그', '해면기압(hPa)', '해면기압 QC플래그',
#        '일조(hr)', '일조 QC플래그', '일사(MJ/m2)', '적설(cm)', '3시간신적설(cm)', '전운량(10분위)',
#        '중하층운량(10분위)', '운형(운형약어)', '최저운고(100m )', '시정(10m)', '지면상태(지면상태코드)',
#        '현상번호(국내식)', '지면온도(°C)', '지면온도 QC플래그', '5cm 지중온도(°C)', '10cm 지중온도(°C)',
#        '20cm 지중온도(°C)', '30cm 지중온도(°C)'],
#       dtype='object')

# %%
temp = 위도경도3.merge(weather, on=['지점', '신고일시2'], how = 'left')

# %%
temp.shape, 위도경도3.shape
# Out:
# ((84247, 47), (84247, 13))

# %%
84496-84310
# Out:
# 186

# %%
temp.to_excel('real.xlsx')
